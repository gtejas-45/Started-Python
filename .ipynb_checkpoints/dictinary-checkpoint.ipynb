# %%
d = {'A':10,'B':20,(1,2,3):[2,3,4,5]}

# %%
d['A']
# Out:
# 10

# %%
d[(1,2,3)]
# Out:
# [2, 3, 4, 5]

# %%
for i in d:
    print(i)#gives the keys
# Out:
# A
# B
# (1, 2, 3)

# %%
for i in d:
    print(d[i])#gives the values
# Out:
# 10
# 20
# [2, 3, 4, 5]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 d[1:]
#
# KeyError: slice(1, None, None)
