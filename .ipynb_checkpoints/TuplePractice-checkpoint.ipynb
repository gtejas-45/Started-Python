# %%
A = (12,1,3,4)

# %% [markdown]
# ##### Indexing

# %%
A[1]
# Out:
# 1

# %%
A[-1]
# Out:
# 4

# %% [markdown]
# ##### Slicing

# %%
A[1:]
# Out:
# (1, 3, 4)

# %%
A[:1]
# Out:
# (12,)

# %%
A[-3:]
# Out:
# (1, 3, 4)

# %% [markdown]
# #### String & Tuple is Immutable

# %%
#A[0] = 15 # Cannot midify content

# %% [markdown]
# ##### Iterable -- It travrse trough tuple element

# %%
for i in A:
    print(i)
# Out:
# 12
# 1
# 3
# 4

# %% [markdown]
# ### Most of the funtions not working in tuple because Tuple is Imutable

# %% [markdown]
# ##### append insert remove pop clear count remove sort copy extend --> All are not working in Tuple
# ##### Only 1) index  2) count

# %%
A.index(12)
# A.index(5) -- gives error becoz element not in tuple
# Out:
# 0

# %%
A.count(12)
# Out:
# 1

# %%
A.count(5) #gives 0 if eement is not
# Out:
# 0
