# %%
S1 = {10,20,30,40,50}
S2 = {40,50,60,70,80}
S3 = {60,70}

# %%
#Union
S1.union(S2)
# Out:
# {10, 20, 30, 40, 50, 60, 70, 80}

# %%
S1.intersection(S2)
# Out:
# {40, 50}

# %%
S1.difference(S2)
# Out:
# {10, 20, 30}

# %%
S2.difference(S1)
# Out:
# {60, 70, 80}

# %%
S1.symmetric_difference(S2)
# Out:
# {10, 20, 30, 60, 70, 80}

# %%
S3.issubset(S2)
# Out:
# True

# %%
S2.issuperset(S3)
# Out:
# True

# %%
S3.isdisjoint(S2)
# Out:
# False

# %%
S1,S2,S3
# Out:
# ({10, 20, 30, 40, 50}, {40, 50, 60, 70, 80}, {60, 70})
