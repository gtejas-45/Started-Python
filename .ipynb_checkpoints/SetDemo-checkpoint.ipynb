# %%
S1 = {10,20,30,40,50}
S2 = {40,50,60,70,80}
S3 = {60,70}

# %%
#Union
S1.union(S2)
# Out:
# {10, 20, 30, 40, 50, 60, 70, 80}

# %%
S1.intersection(S2)
# Out:
# {40, 50}

# %%
S1.difference(S2)
# Out:
# {10, 20, 30}

# %%
S2.difference(S1)
# Out:
# {60, 70, 80}

# %%
S1.symmetric_difference(S2)
# Out:
# {10, 20, 30, 60, 70, 80}

# %%
S3.issubset(S2)
# Out:
# True

# %%
S2.issuperset(S3)
# Out:
# True

# %%
S3.isdisjoint(S2)
# Out:
# False

# %%
S1,S2,S3
# Out:
# ({10, 20, 30, 40, 50}, {40, 50, 60, 70, 80}, {60, 70})

# %%
### Students roll numbered from 1 to 20. phy, che, math
phy = {1,3,5,6,10,12,13,14,18}
che = {2,4,5,6,7,8,11,13,18,19}
math = {2,3,6,9,10,11,17,18,20}

# 1. Roll number opted for phy as well as maths => 3,6,10,18
# 2. Roll numbers opted for all 3 subjects => 6,18
# 3. Roll numbers opted for phy and che but not for math =>5,13,
# 4. Roll numbers opted for exactly 2 subjects =>5,13,3,10,2,11
# 5. Roll numbers not opted any subject => 15,16
# (Hint ALL = set(range(1,21)))

# %%
phy.intersection(math)
# Out:
# {3, 6, 10, 18}

# %%
phy.intersection(math).intersection(che)
# Out:
# {6, 18}

# %%
phy.intersection(che).difference(math)
# Out:
# {5, 13}

# %%
s1 = phy.intersection(math)
s2 = math.intersection(che)
s3 = che.intersection(phy)
s4 = s1.union(s2).union(s3)
s5 = phy.intersection(math).intersection(che)
s4.difference(s5)
# Out:
# {2, 3, 5, 10, 11, 13}

# %%
# a =  phy.union(che).union(math)
# val = []
# cnt = 0
# for i in range(1,21):
#     if i == a[cnt]:
#         continue
#     val.append(i)
#     cnt += 1
# print(val)
#this is not possible becoz set don't have indexing so it cannot accept the index

# %%
ALL = set(range(1,21))
ALL.difference(phy).difference(che).difference(math)
# Out:
# {15, 16}

# %% [markdown]
# ### Set is mutable

# %% [markdown]
# ### Set don't have indexing

# %%
#s[0] not valid

# %% [markdown]
# ### Set is iterable

# %% [markdown]
# ### Set is unorded

# %%
set1 = {10,20,30,40}
for i in set1:
    print(i)
# Out:
# 40
# 10
# 20
# 30

# %% [markdown]
# ### Functions in Sets

# %%
#add inplace of append like in list
s = {10,20,20,'Pune'}
s.add("tej")
s
# Out:
# {10, 20, 'Pune', 'tej'}

# %%
s.add(10)
s#cannot add becoz the 10 is already available
# Out:
# {10, 20, 'Pune', 'tej'}

# %%
s.pop()#random value is poped not fiex value is poped
# Out:
# 'Pune'

# %%
s
# Out:
# {10, 20, 'tej'}

# %%
s.remove(10)

# %%
s
# Out:
# {20, 'tej'}

# %%
#s.remove(10) #gives eror

# %%
s.discard(10) # don't gives eroor and it work like the remove

# %%
s.discard(20)
s
# Out:
# {'tej'}

# %%
s.clear()
s
# Out:
# set()

# %%
s2 = {"Audi","Thar"}
s = {10,20,20,'Pune'}

# %%
s.update(s2)#don't give output only do

# %%
s #basically it union of two set
# Out:
# {10, 20, 'Audi', 'Pune', 'Thar'}

# %% [markdown]
# ### 1)append --> new In set is add()
# ### 2)insert --> we canot place it becoz sets don't have indexing
# ### 3)remove() -->We remove by the element
# ### 4)pop() --> random element poped Not fixed
# ### 5)clear() --> Clear the value in set
# ### 6)index --> Not in sets becoz indexing required
# ### 7)count --> becoz in sets elements are unique
# ### 8)sort --> Sorting is done
# ### 9)copy --> Set is mutable so we can copy Only immutable dataset we cannot copy becoz not necessory
# ### 10)extend --> Not in set we usee update
# ### 11)update()--> union of two sets

# %%
s1 = s.copy()
s1
# Out:
# {10, 20, 'Audi', 'Pune', 'Thar'}

# %% [markdown]
# ### set is Fast data Type
# ### Hash has time colexity is O(1)

# %%
A = list(range(20000000))
S = set(range(20000000))
import time
start = time.time()
1999990 in A
end = time.time()
differ = end - start
differ
# Out:
# 0.026007890701293945

# %%
start = time.time()
1999990 in S
end = time.time()
differ = end - start
differ
# Out:
# 0.0001323223114013672
