# %%
print("Hello world")
name = "tej"
print(f"Hello My name is :{name}")
# Out:
# Hello world
# Hello My name is :tej

# %%
print(r"it's tejas")
# Out:
# it's tejas

# %%
#addition
s = 2
s2 = 4
print(s + s2)
# Out:
# 6

# %%
#squareroot
def s(val):
    return val ** 0.5
s(25)
# Out:
# 5.0

# %%
#perimeter of trianle
def peri(val1,val2,val3):
    return val1+val2+val3
peri(2,3,4)
# Out:
# 9

# %%
#area of triangle when only sides are given
def area1(s1,s2,s3):
    S = (s1+ s2 + s3)/2
    # S = s / 2
    return ((S*(S - s1)*(S - s2)*(S - s3)) ** 0.5)
area1(3,4,5)
# Out:
# 6.0

# %%
#when base and height given 
b = 3
h = 5
area = 0.5 * b * h
print(area)
# Out:
# 7.5

# %%
### Solve Quadratic equation
### ax2 + bx + c = 0 
import cmath
def quadeq(a,b,c):
    d = (b ** 2) - (4 * a *c)
    return  (-b-cmath.sqrt(d))/(2*a) ,  (-b+cmath.sqrt(d))/(2*a)
quadeq(1,5,6)
# Out:
# ((-3-0j), (-2+0j))

# %%
#swap 
a = 5
b = 8
temp = a
a = b
b = temp
a,b
# Out:
# (8, 5)

# %% [markdown]
# ### Random Function

# %%
import random
print(random.random())
# Out:
# 0.2757990879939939

# %%
print(random.randint(2, 8))
# Out:
# 6

# %%
print(random.randrange(1,6))
# Out:
# 5

# %%
print(random.uniform(1.4,2.0)) # floating values
# Out:
# 1.9662437048557706

# %%
#Guess numbers from 1 - 50 
num = random.randint(1,50)
checks = 0
while True:
    num_our = int(input("Enter Number from 1 to 50 : "))
    if num < num_our:
        print("Number is less than",num_our)
    elif num > num_our:
        print("Number is greater than",num_our)
    else:
        print("Number is : ",num_our,"And checks ara " , checks + 1)
        break
    checks += 1
# Out:
# Enter Number from 1 to 50 :  25
# Number is less than 25
# Enter Number from 1 to 50 :  15
# Number is greater than 15
# Enter Number from 1 to 50 :  20
# Number is less than 20
# Enter Number from 1 to 50 :  17
# Number is greater than 17
# Enter Number from 1 to 50 :  19
# Number is less than 19
# Enter Number from 1 to 50 :  18
# Number is :  18 And checks ara  6

# %%
# Km to miles conversion
km = float(input())
def km_to_miles_conversion(km):
    return km / 1.60934
km_to_miles_conversion(km)
# Out:
#  34.28365
# 21.302925422844147

# %%
#convert celsius to frenhite
c = float(input())
f = (c * 1.8) + 32
f
# Out:
#  22
# 71.6

# %%
F = float(input())
c = ((F - 32) * 5) / 9
c
# Out:
#  71.6
# 21.999999999999996

# %%
# + - 0 --> 
inp = int(input())
if inp < 0:
    print("Number is -ve")
elif inp > 0:
    print("Number is +ve")
else:
    print("Number is 0")
# Out:
#  3
# Number is +ve

# %%
#odd even
inp = int(input())
if inp % 2 == 0:
    print("Number is even")
else:
    print("Odd")
# Out:
#  2
# Number is even

# %%
#Check Leap year
inp = int(input())
if inp % 4 == 0:
    print("leap")
else:
    print("normal")
# Out:
#  2004
# leap

# %%
#maximum number from 3 numbers
a = 100
b = 200
c = 30
if a > b:
    if a > c:
        print(f"{a} is gretter")
    else:
        print(f"{c} is gretter")
else:
    if b > c:
        print(f"{b} is gretter")
    else:
        print(f"{c} is gretter")
# Out:
# 200 is gretter

# %%
#check prime number
def prime(val):
    if val <= 1:
        return "Not Prime"
    else:
        for i in range(2,val):
            if (val % i) == 0:
                return "Not prime"
    return "Prime"
prime(4)
# Out:
# 'Not prime'

# %%
# Program to check if a number is prime or not

num = 4

# To take input from the user
#num = int(input("Enter a number: "))

# define a flag variable
flag = False

if num == 0 or num == 1:
    print(num, "is not a prime number")
elif num > 1:
    # check for factors
    for i in range(2, num):
        if (num % i) == 0:
            # if factor is found, set flag to True
            flag = True
            # break out of loop
            break

    # check if flag is True
    if flag:
        print(num, "is not a prime number")
    else:
        print(num, "is a prime number")
# Out:
# 4 is not a prime number

# %%
#print prime numbers from 1 - 100
def prime(val):
    if val <= 1:
        return False
    else:
        for i in range(2,val):
            if (val % i) == 0:
                return False
    return True
#alredy i build the function of prime
prime_list = []
for i in range(1,22):
    if prime(i):
         prime_list.append(i)
prime_list
#list till 22 it gives answer in serial list after 22 it gives in straigt answers means in vertical 
#Becoz the list fits clear in list till 22 at horizantal so it gives in vertical
#if it is greaterthan 22
# Out:
# [2, 3, 5, 7, 11, 13, 17, 19]

# %%
#Factorial of number
fact_list=[]
def fact(val):
    for i in range(1,val):
        if (val % i) == 0:
            fact_list.append(i)
fact(10)
fact_list
# Out:
# [1, 2, 5]

# %%
def mul(val):
    for i in range(1,11):
        val1 = val * i
        print(val1)
mul(5)
# Out:
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45
# 50

# %%
# fibonacci Sequence
fib = []
def fibo(val):
    if val == 0:
        return 0
    if val == 1:
        return 1
    return fibo(val - 1) + fibo(val - 2)
for i in range(5):
    # fib.append(fibo(i))     # if u want to element in list we can use it
    print(fibo(i),end = " ")   #by print also we do like t
# fib
# Out:
# 0 1 1 2 3

# %%
#check armstrong number
n = 153
org = n
arm = 0
while n != 0:
    d = n % 10
    n = n // 10
    arm = arm + (d * d * d) # d*d*d means d ** 3 power
if org == arm:
    print("armstrong")
else:
    print("Not")
# Out:
# armstrong

# %%
#numbers of 3 digits
def isArmstrong(n):
    org = n
    arm = 0
    while n != 0:
        d = n % 10
        n = n // 10
        arm = arm + (d * d * d) # d*d*d means d ** 3 power
    if org == arm:
        return True
    else:
        return False
for i in range(100,900):
    if isArmstrong(i):
        print(i,end = " ")
# Out:
# 1 153 370 371 407
