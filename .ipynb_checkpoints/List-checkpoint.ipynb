# %%
A = [12,20,3.14,"Pune"]#create
print(A)
# Out:
# [12, 20, 3.14, 'Pune']

# %%
for i in A:#iterate
    print(i)
# Out:
# 12
# 20
# 3.14
# Pune

# %%
A[0]#indexing
# Out:
# 12

# %%
A[0] = 15#List is mutable 
print(A)
# Out:
# [15, 20, 3.14, 'Pune']

# %%
A[-1][-1]
# Out:
# 'e'

# %%
A[2:]
# Out:
# [3.14, 'Pune']

# %%
A[:-3]#slicing
# Out:
# [15]

# %%
B = [5,2,4,7,3]
t = 0
for i in B:
    t = t + i
print(t)
# Out:
# 21

# %%
t = 0
for i in B:
    if i % 2 == 0:
        t = t + i
print(t)
# Out:
# 6

# %%
m = B[0]
for i in B:
    if i > m:
        m = i
print(m)
# Out:
# 7

# %%
m = B[0]
for i in B:
    if i < m:
        m = i
print(m)
# Out:
# 2

# %%
#addition of even index 
i = 0
add = 0
while i < len(B):
    if i % 2 == 0:
        add = add + B[i]
    i += 1
print(add)
# Out:
# 12

# %%
name = ['Mr.Pratik Patil','Ms.Mayuri Rajmane','Mr.Gajanan Kulkarni','Mrs.Priya Rai']
#longest length name
m = len(name[0])
n = ""
for i in name:
    if len(i) > m:
       # m = len(i)
        n = i
        
print(n)
# Out:
# Mr.Gajanan Kulkarni

# %%
#write a code to print surname only
for i in name:
    print(i.split(" ")[1])
# Out:
# Patil
# Rajmane
# Kulkarni
# Rai

# %%
#write a code to print female names only
for i in name:
    if i.split()[0].startswith('Ms') or i.split()[0].startswith('Mrs'):
        print(i)
# Out:
# Ms.Mayuri Rajmane
# Mrs.Priya Rai

# %%
A = [10,20,30,40]
A.append(30)#add at the content at last 
#it don't print anything

# %%
print(A)
# Out:
# [10, 20, 30, 40, 30]

# %%
A.insert(2,25)#insert at index 2 value is 25
print(A)
# Out:
# [10, 20, 25, 30, 40, 30]

# %%
A.remove(30)#remove first 30
print(A)
# Out:
# [10, 20, 25, 40, 30]

# %%
A.remove(30)#remove second
print(A)
# Out:
# [10, 20, 25, 40]

# %%
A.pop(2)#remove 2nd index element
print(A)
# Out:
# [10, 20, 40]

# %%
A.pop()#default it is pop(-1) --> remove last elemnt like pop in stack
print(A)
# Out:
# [10, 20]

# %%
d = A.clear()#clear all content of list not string
print(d)#it gives none becuse it doesn't change anything becoz it is mutable 
print(A)#delete content of list
# Out:
# None
# []

# %%
A = [2,6,0,3]
n = A.index(3)# gives index and store in n variable
print(n)
# Out:
# 3

# %%
#n = A.index(10)#gives error

# %%
m = A.count(10)#if element not present gives 0
print(m)
# Out:
# 0

# %%
m = A.count(0)#if element present gives count 
print(m)
# Out:
# 1

# %%
A.reverse()
print(A)
# Out:
# [3, 0, 6, 2]

# %%
A.sort()#sort in asending low --> high
print(A)
# Out:
# [0, 2, 3, 6]

# %%
# A.sort(reverse = True)
# print(A)
A = [0, 2, 3, 6]
A.sort(reverse=True)  
print(A)
# Out:
# [6, 3, 2, 0]

# %%
A = [1,2,3]  #A -- [1,2,3] and b refers same to it b[0] = -1 it shows like [-1,2,3]
b = A
b[0] = -1
print(A)
# Out:
# [-1, 2, 3]

# %%
c = A.copy()
print(c)
# Out:
# [-1, 2, 3]

# %%
A,b,c
# Out:
# ([-1, 2, 3], [-1, 2, 3], [-1, 2, 3])

# %%
A = [10,20,30]
B = ['raj','sham']
A.append(B)
len(A)#it should gives the 5 but gives 4
# Out:
# 4

# %%
A#gives nested list in list
# Out:
# [10, 20, 30, ['raj', 'sham']]

# %%
A.pop()
# Out:
# ['raj', 'sham']

# %%
A.extend(B)#it gives the seprate

# %%
A
# Out:
# [10, 20, 30, 'raj', 'sham']

# %%
len(A)
# Out:
# 5

# %%
A.extend('@$')
A#Iterative elemnts that string is of iterative
# Out:
# [10, 20, 30, 'raj', 'sham', '@', '$']
