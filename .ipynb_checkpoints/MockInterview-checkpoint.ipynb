# %%
num = 12
s = 8
s1 = num / s
s1
# Out:
# 1.5

# %%
numbers = [1, 2, 3, 4]

for n in numbers: # 1 2 
    if n % 2 == 0:
        numbers.remove(n)

print(numbers) #1 3
# Out:
# [1, 3]

# %%
# Second largest
val = [2,6,1,9]
val2 = []
max = 0
for i in val:
    val1 = val[0]
    if val1 < val[i]:
